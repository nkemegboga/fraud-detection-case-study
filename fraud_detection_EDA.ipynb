# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading in the data into a dataframe

# %%
df_fraud = pd.read_json('data.json')

# %% [markdown]
# ### Understanding features in the data

# %%
df_fraud.head(2)
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
#
#                                          description email_domain  \
# 0  <p><a href="http://s432.photobucket.com/albums...    gmail.com
# 1  <p>Join us for a quick, one-night, community-b...      ruf.org
#
#    event_created     ...      \
# 0     1262739706     ...
# 1     1293832670     ...
#
#                                         ticket_types  user_age  user_created  \
# 0  [{u'event_id': 527017, u'cost': 25.0, u'availa...        36    1259613950
# 1  [{u'event_id': 786878, u'cost': 35.0, u'availa...       149    1280942776
#
#    user_type          venue_address  venue_country  venue_latitude  \
# 0          1  717 Washington Avenue             US       25.777471
# ...

# %%
df_fraud.columns
# Out:
# Index([u'acct_type', u'approx_payout_date', u'body_length', u'channels',
#        u'country', u'currency', u'delivery_method', u'description',
#        u'email_domain', u'event_created', u'event_end', u'event_published',
#        u'event_start', u'fb_published', u'gts', u'has_analytics',
#        u'has_header', u'has_logo', u'listed', u'name', u'name_length',
#        u'num_order', u'num_payouts', u'object_id', u'org_desc',
#        u'org_facebook', u'org_name', u'org_twitter', u'payee_name',
#        u'payout_type', u'previous_payouts', u'sale_duration',
#        u'sale_duration2', u'show_map', u'ticket_types', u'user_age',
#        u'user_created', u'user_type', u'venue_address', u'venue_country',
#        u'venue_latitude', u'venue_longitude', u'venue_name', u'venue_state'],
#       dtype='object')

# %%
df_fraud.shape
# Out:
# (14337, 44)

# %%
df_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
for column in df_fraud.columns:
    print column,": ", df_fraud[column][0:10]
# Out:
# acct_type :  0    fraudster_event
# 1            premium
# 2            premium
# 3            premium
# 4            premium
# 5            premium
# 6            premium
# 7            premium
# 8            premium
# 9            premium
# Name: acct_type, dtype: object
# approx_payout_date :  0    1266062400
# 1    1296720000
# 2    1296172800
# 3    1388966400
# 4    1297900800
# 5    1300496400
# 6    1297909800
# 7    1296709200
# 8    1298185200
# 9    1297314000
# Name: approx_payout_date, dtype: int64
# body_length :  0     3852
# 1     3499
# 2     2601
# 3    12347
# 4     2417
# 5      117
# 6       28
# 7      974
# 8     4388
# 9      974
# Name: body_length, dtype: int64
# channels :  0     5
# 1     0
# 2     8
# 3     6
# 4    11
# 5     6
# 6     5
# 7    12
# 8     4
# 9    12
# Name: channels, dtype: int64
# country :  0    US
# 1    US
# 2    US
# 3    IE
# 4    US
# 5    US
# 6    US
# 7    US
# 8    US
# 9    US
# Name: country, dtype: object
# ...

# %% [markdown]
# ### The 'ticket_types' and 'previous_payouts' columns  are made up of dictionaries

# %%
df_fraud.ticket_types[0]
# Out:
# [{u'availability': 1,
#   u'cost': 25.0,
#   u'event_id': 527017,
#   u'quantity_sold': 0,
#   u'quantity_total': 800},
#  {u'availability': 1,
#   u'cost': 50.0,
#   u'event_id': 527017,
#   u'quantity_sold': 0,
#   u'quantity_total': 100},
#  {u'availability': 1,
#   u'cost': 550.0,
#   u'event_id': 527017,
#   u'quantity_sold': 0,
#   u'quantity_total': 20}]

# %%
df_fraud.previous_payouts[1432]
# Out:
# [{u'address': u'68 Jay Street #203',
#   u'amount': 189.0,
#   u'country': u'US',
#   u'created': u'2012-01-17 03:11:14',
#   u'event': 2701415,
#   u'name': u'Fulton Ferry Market, Inc.',
#   u'state': u'NY',
#   u'uid': 4951781,
#   u'zip_code': u'11201'},
#  {u'address': u'68 Jay Street #203',
#   u'amount': 273.0,
#   u'country': u'US',
#   u'created': u'2012-02-15 03:20:38',
#   u'event': 2865259,
#   u'name': u'REBAR',
#   u'state': u'NY',
#   u'uid': 4951781,
#   u'zip_code': u'11201'},
#  {u'address': u'68 Jay Street #203',
#   u'amount': 329.0,
#   u'country': u'US',
#   u'created': u'2012-02-16 03:20:43',
#   u'event': 2865259,
#   u'name': u'REBAR',
#   u'state': u'NY',
#   u'uid': 4951781,
#   u'zip_code': u'11201'},
#  {u'address': u'68 Jay Street #203',
#   u'amount': 21.0,
#   u'country': u'US',
#   u'created': u'2012-02-17 03:20:26',
#   u'event': 2865259,
#   u'name': u'REBAR',
#   u'state': u'NY',
#   u'uid': 4951781,
#   u'zip_code': u'11201'},
# ...

# %% [markdown]
# ### Analyzing the 'acct_type' column, which gives information about if the event is fraud vs. not fraud

# %%
df_fraud.acct_type.unique()
# Out:
# array([u'fraudster_event', u'premium', u'spammer_warn', u'fraudster',
#        u'spammer_limited', u'spammer_noinvite', u'locked', u'tos_lock',
#        u'tos_warn', u'fraudster_att', u'spammer_web', u'spammer'], dtype=object)

# %%
df_fraud.acct_type.value_counts()
# Out:
# premium             12373
# fraudster_event       851
# fraudster             437
# spammer_limited       218
# spammer_warn          144
# tos_warn               91
# spammer_noinvite       84
# tos_lock               77
# locked                 54
# fraudster_att           5
# spammer_web             2
# spammer                 1
# Name: acct_type, dtype: int64

# %% [markdown]
# ### The 'email_domain' column. We will only use the 30 most popular domain names as classes and group all others as 'other'

# %%
df_fraud.email_domain.value_counts()
# Out:
# gmail.com                       3097
# yahoo.com                        792
# hotmail.com                      399
# aol.com                          198
# live.com                          80
# me.com                            75
# ymail.com                         68
# comcast.net                       60
# generalassemb.ly                  58
# kineticevents.com                 52
# yahoo.co.uk                       52
# hotmail.co.uk                     48
# improvboston.com                  46
# sippingnpainting.com              39
# claytonislandtours.com            37
# lidf.co.uk                        35
# racetonowhere.com                 35
# live.fr                           33
# greatworldadventures.com          31
# yahoo.ca                          31
# shaw.ca                           28
# sbcglobal.net                     26
# msn.com                           25
# mac.com                           25
# guardian.co.uk                    24
# ...
