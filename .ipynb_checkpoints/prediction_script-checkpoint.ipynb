# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import cPickle as pickle
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from string import punctuation
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import pymongo
from pymongo import MongoClient
from fraud_detection_feature_eng import tokenize, prep_data
import requests
import json
import ast
from datetime import date

# %%
client = MongoClient()
db = client.fraud_detector
db.fraud_table.remove()
table = db.fraud_table
# Out:
# /Users/gstudent/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def feed_db(df, probabilities, table):
    df_data = pd.concat(objs = [df, pd.DataFrame(probabilities, columns=['fraud_probability'])], axis=1)
    df_data = df_data.T.to_dict().values()
    table.insert(df_data)

# %%
col_names = [u'approx_payout_date',
 u'body_length',
 u'channels',
 u'country',
 u'currency',
 u'delivery_method',
 u'description',
 u'email_domain',
 u'event_created',
 u'event_end',
 u'event_published',
 u'event_start',
 u'fb_published',
 u'gts',
 u'has_analytics',
 u'has_header',
 u'has_logo',
 u'listed',
 u'name',
 u'name_length',
 u'num_order',
 u'num_payouts',
 u'object_id',
 u'org_desc',
 u'org_facebook',
 u'org_name',
 u'org_twitter',
 u'payee_name',
 u'payout_type',
 u'previous_payouts',
 u'sale_duration',
 u'sale_duration2',
 u'show_map',
 u'ticket_types',
 u'user_age',
 u'user_created',
 u'user_type',
 u'venue_address',
 u'venue_country',
 u'venue_latitude',
 u'venue_longitude',
 u'venue_name',
 u'venue_state']

# %%
html = requests.get('http://galvanize-case-study-on-fraud.herokuapp.com/data_point')
fraud_dict = html.json()

df = pd.DataFrame(columns=col_names)
df = df.append(fraud_dict, ignore_index=True)

df_, X_data = prep_data(df)
with open('pickle/model.pkl') as f:
    model = pickle.load(f)
probabilities = model.predict_proba(X_data)[:,1]
feed_db(df, probabilities, table)
# Out:
# /Users/gstudent/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   after removing the cwd from sys.path.

# %%
lisst_ = []
for i in db.fraud_table.find( {}, { 'org_name': 1, 'name': 1, 'event_start' : 1, 'event_created':1, 'country' : 1 ,'object_id':1, '_id':0, 'fraud_probability':1 }):
    i = ast.literal_eval(json.dumps(i))
    i['event_created'] = date.fromtimestamp(int(i['event_created'])).__str__()
    i['event_start'] = date.fromtimestamp(int(i['event_start'])).__str__()
    if i['fraud_probability'] > 0.9:
        i['risk'] = 'High'
        i['style'] = "<td style='background-color: #FF9999'>"
    elif i['fraud_probability'] < 0.01:
        i['risk'] = 'Low'
        i['style'] = "<td style='background-color: #ADDEAD'>"
    else:
        i['risk'] = 'Medium'
        i['style'] = "<td style='background-color: #b0eaf6'>"
    lisst_.append(i)
print lisst_
# Out:
# [{'org_name': 'Cross Campus', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Game Changing Entrepreneurs - A Panel Discussion', 'country': 'US', 'event_start': '2012-09-27', 'event_created': '2012-09-06', 'object_id': 4190428.0, 'fraud_probability': 5.493556454894133e-05, 'risk': 'Low'}, {'org_name': 'Canterbury Shaker Village', 'style': "<td style='background-color: #ADDEAD'>", 'name': '"Traveling Home" Kevin Siegfried in Concert', 'country': 'US', 'event_start': '2013-06-23', 'event_created': '2013-02-25', 'object_id': 5613720.0, 'fraud_probability': 0.00011659046867862344, 'risk': 'Low'}, {'org_name': 'CIBSE NSW Chapter', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'ETHICS', 'country': 'AU', 'event_start': '2013-05-07', 'event_created': '2013-04-23', 'object_id': 6386431.0, 'fraud_probability': 0.0005387412384152412, 'risk': 'Low'}, {'org_name': 'JOIN DR. JEAN PEREZ & CLUB INTERCESSION IN ATLANTA, GA.!', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'ATLANTA ABLAZE WITH PRAISE JULY, FRI., 19, SAT.,  20 & SUN., 21, 2013', 'country': 'US', 'event_start': '2013-07-19', 'event_created': '2013-04-15', 'object_id': 6279399.0, 'fraud_probability': 0.00046215622569434345, 'risk': 'Low'}, {'org_name': 'OLF Training Centre', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Maxwell Mobility and Body Weight Conditioning System.', 'country': 'GB', 'event_start': '2012-07-22', 'event_created': '2012-03-28', 'object_id': 3239543.0, 'fraud_probability': 0.00010703933367040008, 'risk': 'Low'}, {'org_name': 'LUXURY RAP SF', 'style': "<td style='background-color: #ADDEAD'>", 'name': "The Red & Gold Party | 111 Minna Gallery | GiGi's Guests ", 'country': 'US', 'event_start': '2013-03-16', 'event_created': '2013-03-06', 'object_id': 5728340.0, 'fraud_probability': 5.493556454894133e-05, 'risk': 'Low'}, {'org_name': 'CoLab (AUT University)', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Cardboard Synthesizer Workshop', 'country': 'NZ', 'event_start': '2013-05-30', 'event_created': '2013-05-06', 'object_id': 6132143.0, 'fraud_probability': 0.0001498324127169326, 'risk': 'Low'}, {'org_name': 'British School of Osteopathy (BSO)', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Nutrition in Practice', 'country': 'GB', 'event_start': '2013-01-12', 'event_created': '2012-05-23', 'object_id': 3602303.0, 'fraud_probability': 6.186190876178443e-05, 'risk': 'Low'}, {'org_name': '1015 Folsom', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Just Blaze + Hudson Mohawke + Araab Muzik + Take + The Blessings', 'country': 'US', 'event_start': '2011-03-12', 'event_created': '2011-02-02', 'object_id': 1271871.0, 'fraud_probability': 7.867198291933164e-05, 'risk': 'Low'}, {'org_name': 'CWSHRM', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'CWSHRM Membership Renewal', 'country': 'US', 'event_start': '2012-12-31', 'event_created': '2012-10-25', 'object_id': 4486842.0, 'fraud_probability': 0.00028850408853031695, 'risk': 'Low'}, {'org_name': '', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Singles Conference "Singles Moving Mountains to Awaken your Purpose"', 'country': 'US', 'event_start': '2012-08-11', 'event_created': '2012-07-03', 'object_id': 3849202.0, 'fraud_probability': 0.00012104708730475977, 'risk': 'Low'}, {'org_name': 'LIDF', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Invisible City - London', 'country': 'GB', 'event_start': '2012-06-22', 'event_created': '2012-05-13', 'object_id': 3536133.0, 'fraud_probability': 0.007374903187155724, 'risk': 'Low'}, {'org_name': 'Alumni Relations', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Misselwood Jazz', 'country': 'US', 'event_start': '2013-07-16', 'event_created': '2013-06-19', 'object_id': 7138827.0, 'fraud_probability': 0.0007610120810568333, 'risk': 'Low'}, {'org_name': 'The Big Mix', 'style': "<td style='background-color: #ADDEAD'>", 'name': 'Parallel Lines pr ...

# %%
fraud_file = pd.read_csv('plots/graphfraud.csv')
not_fraud_file = pd.read_csv('plots/graphnotfraud.csv')

from bokeh.plotting import figure, show, output_notebook
from bokeh.embed import components
from bokeh.resources import CDN
output_notebook()

p = figure(title="Fraud Visualization")
p.background_fill_color = "#eeeeee"

p.scatter(not_fraud_file.values[:,0],not_fraud_file.values[:,1],marker='triangle',color='orange',legend='Not Fraud')
p.scatter(fraud_file.values[:,0],fraud_file.values[:,1],marker='circle',color='red',legend='Fraud')
# p.scatter(dfsavy.values[1,0],dfsavy.values[1,1],color='blue',legend='new',marker='square',size=20)
show(p)

script, div = components(p)

div = ast.literal_eval(json.dumps(div)).replace('\n', "")
script = ast.literal_eval(json.dumps(script)).replace('\n', "")
css = CDN.render_css()
css = ast.literal_eval(json.dumps(css)).replace('\n', "")
js = CDN.render_js()
js = ast.literal_eval(json.dumps(js)).replace('\n', "")

# %%
with open('plots/pca.pkl') as f:
    pca = pickle.load(f)
    
with open('plots/scaler.pkl') as f:
    scaler = pickle.load(f)
    
(x,y) = pca.transform(scaler.transform(df.values))

# %%
lisst_1 = []
for i in db.fraud_table.find( {}, {'_id':0}):
    print i
    
    i = ast.literal_eval(json.dumps(i))
    lisst_1.append(i)
print lisst_1
# Out:
# {u'types_count': 2.0, u'name_length': 48.0, u'event_end': 1348806600.0, u'venue_latitude': 34.0184893, u'event_published': 1346976903.0, u'user_type': 4.0, u'quantity_total': 300.0, u'fb_published': 0.0, u'channels': 11.0, u'currency': u'USD', u'org_desc': u'<p><span style="font-size: medium; font-family: helvetica;"><span style="color: #ffffff;"><strong><br /></strong></span></span></p>\r\n<p><span style="font-size: medium; font-family: helvetica;"><span style="color: #ffffff;"><strong><span style="color: #aff8fc;">GET SERIOUS</span><br /><span style="color: #00ccff;">GET SMARTER</span><br /></strong></span><strong><span style="color: #3366ff;">BUILD BETTER</span>&nbsp;</strong></span></p>', u'event_created': 1346968928.0, u'approx_payout_date': 1349238600.0, u'has_logo': 1.0, u'email_domain': u'other', u'user_created': 1302848590.0, u'user_age': 511.0, u'payee_name': 1.0, u'value_sold': 573.12, u'description': u'<p class="MsoNormal"><strong><span style="font-size: 16.0pt; font-family: \'Helvetica Neue\'; mso-bidi-font-family: \'Helvetica Neue\'; color: #185484;">Game Changing Entrepreneurs -&nbsp;A Panel Discussion &amp; Networking Event<br /></span></strong></p>\r\n<p class="MsoNormal"><em><span style="font-size: 13.5pt; font-family: Helvetica; mso-fareast-font-family: \'Times New Roman\'; mso-bidi-font-family: Helvetica; color: #4b4b4b;">Thursday, September 27th from 6:00 PM to 9:30 PM</span></em></p>\r\n<p class="MsoNormal"><strong><span style="font-size: 16.0pt; font-family: \'Helvetica Neue\'; mso-bidi-font-family: \'Helvetica Neue\'; color: #7f7f7f; mso-themecolor: text1; mso-themetint: 128;">Moderated by&nbsp;Josh Ochs from MediaLeaders with Panelists Costas Roussos (.music), Scott Ferreira (MySocialCloud), Edo Cohen (SeeVolution) and Nicholas Smoot (HereOnBiz)<br /></span></strong></p>\r\n<p class="MsoNormal" style="background: white;"><span style="font-size: small; font-family: arial, helvetica, sans-serif; color: #2c2c2c;">How do you differentiate yourself in a world full of great ideas and causes?&nbsp; How do you turn your passion and mission into a groundswell of energy that can touch millions of lives?&nbsp; Join us for an interactive discussion with four outstanding entrepreneurs and luminaries as they discuss their passion and how they were able to light people up with it.&nbsp; Whether it\'s Costa\'s campaign to bring to life the .MUSIC domain name or Scott getting Sir Richard Branson to invest in his startup MySocialCloud, what these entrepreneurs have in common is an understanding of the power of social media and an ability to charge people up with their mission.</span></p>\r\n<p class="MsoNormal" style="background: white;"><span style="font-size: small; font-family: arial, helvetica, sans-serif; color: #2c2c2c;">&nbsp;</span></p>\r\n<p class="MsoListParagraphCxSpFirst" style="margin-left: 1.0in; mso-add-space: auto; text-indent: -.25in; mso-list: l0 level1 lfo1; background: white;"><span style="font-size: small; font-family: arial, helvetica, sans-serif;"><!--[if !supportLists]--><span style="color: #2c2c2c;">&middot;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span><!--[endif]--><span style="color: #2c2c2c;">6:00 - 6:30 - Cocktails, Hors D\' Oeuvres &amp; Networking</span></span></p>\r\n<p class="MsoListParagraphCxSpMiddle" style="margin-left: 1.0in; mso-add-space: auto; text-indent: -.25in; mso-list: l0 level1 lfo1; background: white;"><span style="font-size: small; font-family: arial, helvetica, sans-serif;"><!--[if !supportLists]--><span style="color: #2c2c2c;">&middot;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span><!--[endif]--><span style="color: #2c2c2c;">6:30 - 7:15 -&nbsp;Panel Discussion with Costa, Alex, Edo and Nicholas<br /></span></span></p>\r\n<p class="MsoListParagraphCxSpMiddle" style="margin-left: 1.0in; mso-add-space: auto; text-indent: -.25in; mso-list: l0 level1 lfo1; background: white;"><span style="font-size: small; font-family: arial, helvetica, sans-serif;"><!--[if !supportLists]--><span style="color: ...
# {u'types_count': 3.0, u'name_length': 43.0, u'event_end': 1372030200.0, u'venue_latitude': 43.3587942, u'event_published': 1361807762.0, u'user_type': 1.0, u'quantity_total': 150.0, u'fb_published': 0.0, u'channels': 5.0, u'currency': u'USD', u'org_desc': u'<p><span style="font-size: small;">Canterbury Shaker Village, Inc., is an internationally-known non-profit museum dedicated&nbsp;to preserving the 200-year legacy of the Canterbury Shakers and to providing a place for <span style="font-size: small;">learning, reflection, and renewal of the human spirit.</span></span></p>\r\n<p><span style="font-size: small;">Designated as a National Historic Landmark for its architectural integrity and significance, the Village has 25 restored original Shaker buildings, 4 reconstructed Shaker buildings, and 694 acres of forests, fields, gardens, nature trails, and mill ponds under permanent conservation easement.</span></p>\r\n<p><span style="font-size: small;"><span style="font-size: small;">Canterbury Shaker Village offers visitors a variety of engaging experiences in one of the most picturesque settings in northern New England. Find your inspiration in hands-on workshops, events,&nbsp;exhibits, tours, and demonstrations. Shop for regional handcrafts in the museum store and enjoy lunch at the Farm Stand Cafe. Visit us at <a href="http://www.shakers.org">www.shakers.org</a></span></span></p>\r\n<p><span style="font-size: small;"><span style="font-size: small;">&nbsp;</span></span></p>\r\n<p>&nbsp;</p>', u'event_created': 1361806463.0, u'approx_payout_date': 1372462200.0, u'has_logo': 1.0, u'email_domain': u'other', u'user_created': 1330465407.0, u'user_age': 363.0, u'payee_name': 0.0, u'value_sold': 187.0, u'description': u'<p><strong><span style="font-family: book antiqua,palatino; font-size: medium;">Kevin Siegfried in concert, "Traveling Home"</span></strong></p>\r\n<p><strong><span style="font-family: book antiqua,palatino; font-size: medium;">Sunday, June 23rd, 2013, 3:00pm</span></strong></p>\r\n<p><strong><span style="font-family: book antiqua,palatino; font-size: medium;">Tickets are $17.00 for adults, $8.00 for children aged 6-17, children 5 years and under attend free.&nbsp; Tickets include museum pass.</span></strong><span style="font-family: Times New Roman; font-size: medium;"><span style="font-size: 12pt;">&nbsp;</span></span></p>\r\n<p><span style="font-family: Times New Roman; font-size: medium;"><span style="font-size: 12pt;"><span style="font-family: book antiqua,palatino;">Joined by a small choral ensemble, Kevin Siegfried will lead a journey into our fascinating American musical heritage, performing rarely heard gems from the vast Shaker repertoire amidst a backdrop of other early American musical styles. </span></span></span></p>\r\n<p><span style="font-family: Times New Roman; font-size: medium;"><span style="font-size: 12pt;"><span style="font-family: book antiqua,palatino;">Siegfried has been hard at work in the Shaker archives, and those in attendance will hear captivating, newly uncovered melodies from the Canterbury Shakers and beyond. A composer and singer with a deep, abiding love of Shaker music, Siegfried has actively sought to inspire interest in the music of the Shakers, and his award-winning choral arrangements of Shaker songs have been recorded and performed throughout the world.</span> </span></span></p>\r\n<p><span style="font-family: Times New Roman; font-size: medium;"><span style="font-size: 12pt;"><span style="font-family: Book Antiqua;">We invite our Village Visionary members to reserve their seats by calling Development Director, Sally Stanton at least 2 days before the concert at 603-783-9077 x285.</span></span></span></p>\r\n<p>&nbsp;</p>', u'object_id': 5613720.0, u'venue_name': u'Canterbury Shaker Village', u'sale_duration2': 118.0, u'venue_address': u'288 Shaker Rd', u'avg_payout': 125.46285714285716, u'event_start': 1372024800.0, u'org_twitter': 0.0, u'gts': 208.23, u'payout_type': u'ACH', u ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-220-ae697ac32fdc> in <module>()
#       2 for i in db.fraud_table.find( {}, {'_id':0}):
#       3     print i
# ----> 4     i = ast.literal_eval(json.dumps(i))
#       5     lisst_1.append(i)
#       6 print lisst_1
#
# /Users/gstudent/anaconda2/lib/python2.7/ast.pyc in literal_eval(node_or_string)
#      78                 return left - right
#      79         raise ValueError('malformed string')
# ---> 80     return _convert(node_or_string)
#      81
#      82
#
# /Users/gstudent/anaconda2/lib/python2.7/ast.pyc in _convert(node)
#      61         elif isinstance(node, Dict):
#      62             return dict((_convert(k), _convert(v)) for k, v
# ---> 63                         in zip(node.keys, node.values))
#      64         elif isinstance(node, Name):
#      65             if node.id in _safe_names:
#
# /Users/gstudent/anaconda2/lib/python2.7/ast.pyc in <genexpr>((k, v))
#      60             return list(map(_convert, node.elts))
#      61         elif isinstance(node, Dict):
# ---> 62             return dict((_convert(k), _convert(v)) for k, v
#      63                         in zip(node.keys, node.values))
#      64         elif isinstance(node, Name):
#
# /Users/gstudent/anaconda2/lib/python2.7/ast.pyc in _convert(node)
#      77             else:
#      78                 return left - right
# ---> 79         raise ValueError('malformed string')
#      80     return _convert(node_or_string)
#      81
#
# ValueError: malformed string

# %%
print i
# Out:
# {u'types_count': 3.0, u'name_length': 43.0, u'event_end': 1372030200.0, u'venue_latitude': 43.3587942, u'event_published': 1361807762.0, u'user_type': 1.0, u'quantity_total': 150.0, u'fb_published': 0.0, u'channels': 5.0, u'currency': u'USD', u'org_desc': u'<p><span style="font-size: small;">Canterbury Shaker Village, Inc., is an internationally-known non-profit museum dedicated&nbsp;to preserving the 200-year legacy of the Canterbury Shakers and to providing a place for <span style="font-size: small;">learning, reflection, and renewal of the human spirit.</span></span></p>\r\n<p><span style="font-size: small;">Designated as a National Historic Landmark for its architectural integrity and significance, the Village has 25 restored original Shaker buildings, 4 reconstructed Shaker buildings, and 694 acres of forests, fields, gardens, nature trails, and mill ponds under permanent conservation easement.</span></p>\r\n<p><span style="font-size: small;"><span style="font-size: small;">Canterbury Shaker Village offers visitors a variety of engaging experiences in one of the most picturesque settings in northern New England. Find your inspiration in hands-on workshops, events,&nbsp;exhibits, tours, and demonstrations. Shop for regional handcrafts in the museum store and enjoy lunch at the Farm Stand Cafe. Visit us at <a href="http://www.shakers.org">www.shakers.org</a></span></span></p>\r\n<p><span style="font-size: small;"><span style="font-size: small;">&nbsp;</span></span></p>\r\n<p>&nbsp;</p>', u'event_created': 1361806463.0, u'approx_payout_date': 1372462200.0, u'has_logo': 1.0, u'email_domain': u'other', u'user_created': 1330465407.0, u'user_age': 363.0, u'payee_name': 0.0, u'value_sold': 187.0, u'description': u'<p><strong><span style="font-family: book antiqua,palatino; font-size: medium;">Kevin Siegfried in concert, "Traveling Home"</span></strong></p>\r\n<p><strong><span style="font-family: book antiqua,palatino; font-size: medium;">Sunday, June 23rd, 2013, 3:00pm</span></strong></p>\r\n<p><strong><span style="font-family: book antiqua,palatino; font-size: medium;">Tickets are $17.00 for adults, $8.00 for children aged 6-17, children 5 years and under attend free.&nbsp; Tickets include museum pass.</span></strong><span style="font-family: Times New Roman; font-size: medium;"><span style="font-size: 12pt;">&nbsp;</span></span></p>\r\n<p><span style="font-family: Times New Roman; font-size: medium;"><span style="font-size: 12pt;"><span style="font-family: book antiqua,palatino;">Joined by a small choral ensemble, Kevin Siegfried will lead a journey into our fascinating American musical heritage, performing rarely heard gems from the vast Shaker repertoire amidst a backdrop of other early American musical styles. </span></span></span></p>\r\n<p><span style="font-family: Times New Roman; font-size: medium;"><span style="font-size: 12pt;"><span style="font-family: book antiqua,palatino;">Siegfried has been hard at work in the Shaker archives, and those in attendance will hear captivating, newly uncovered melodies from the Canterbury Shakers and beyond. A composer and singer with a deep, abiding love of Shaker music, Siegfried has actively sought to inspire interest in the music of the Shakers, and his award-winning choral arrangements of Shaker songs have been recorded and performed throughout the world.</span> </span></span></p>\r\n<p><span style="font-family: Times New Roman; font-size: medium;"><span style="font-size: 12pt;"><span style="font-family: Book Antiqua;">We invite our Village Visionary members to reserve their seats by calling Development Director, Sally Stanton at least 2 days before the concert at 603-783-9077 x285.</span></span></span></p>\r\n<p>&nbsp;</p>', u'object_id': 5613720.0, u'venue_name': u'Canterbury Shaker Village', u'sale_duration2': 118.0, u'venue_address': u'288 Shaker Rd', u'avg_payout': 125.46285714285716, u'event_start': 1372024800.0, u'org_twitter': 0.0, u'gts': 208.23, u'payout_type': u'ACH', u ...

# %%
str(0)
# Out:
# '0'
